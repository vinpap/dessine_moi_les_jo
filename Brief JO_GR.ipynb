# %% [markdown]
# # Brief JO

# %% [markdown]
# ### Import the packages

# %%
# Import the packages
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### Read the files and display what they have inside them

# %%
# Read the files
athletes = pd.read_csv("data/olympic_athletes.csv")
medals = pd.read_csv("data/olympic_medals.csv")
hosts = pd.read_csv("data/olympic_hosts.csv")
results = pd.read_csv("data/olympic_results.csv")
results_pkl = pd.read_pickle("data/olympic_results.pkl")

# %%
athletes.head()
# Out:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0            NaN
# 1                     2  PyeongChang 2018              1995.0            NaN
# 2                     1      Beijing 2022              1993.0            NaN
# 3                     1      Beijing 2022              1995.0            NaN
# 4                     1      Beijing 2022              1989.0            NaN
#
#    bio
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
medals.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# 2  https://olympics.com/en/athletes/kristin-skaslien      Kristin SKASLIEN
# 3  https://olympics.com/en/athletes/magnus-nedreg...    Magnus NEDREGOTTEN
# 4     https://olympics.com/en/athletes/almida-de-val         Almida DE VAL
#
#   country_name country_code country_3_letter_code
# 0        Italy           IT                   ITA
# 1        Italy           IT                   ITA
# 2       Norway           NO                   NOR
# 3       Norway           NO                   NOR
# 4       Sweden           SE                   SWE

# %%
hosts.head()
# Out:
#           game_slug         game_end_date       game_start_date  \
# 0      beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z
# 1        tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z
# 2  pyeongchang-2018  2018-02-25T08:00:00Z  2018-02-08T23:00:00Z
# 3          rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z
# 4        sochi-2014  2014-02-23T16:00:00Z  2014-02-07T04:00:00Z
#
#         game_location         game_name game_season  game_year
# 0               China      Beijing 2022      Winter       2022
# 1               Japan        Tokyo 2020      Summer       2020
# 2   Republic of Korea  PyeongChang 2018      Winter       2018
# 3              Brazil          Rio 2016      Summer       2016
# 4  Russian Federation        Sochi 2014      Winter       2014

# %%
results.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                             athletes rank_equal rank_position  \
# 0  [('Stefania CONSTANTINI', 'https://olympics.co...      False             1
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en...      False             2
# 2  [('Almida DE VAL', 'https://olympics.com/en/at...      False             3
# 3  [('Jennifer DODDS', 'https://olympics.com/en/a...      False             4
# 4  [('Rachel HOMAN', 'https://olympics.com/en/ath...      False             5
#
#     country_name country_code country_3_letter_code athlete_url  \
# 0          Italy           IT                   ITA         NaN
# 1         Norway           NO                   NOR         NaN
# 2         Sweden           SE                   SWE         NaN
# 3  Great Britain           GB                   GBR         NaN
# 4         Canada           CA                   CAN         NaN
#
#   athlete_full_name value_unit value_type
# 0               NaN        NaN        NaN
# 1               NaN        NaN        NaN
# 2               NaN        NaN        NaN
# 3               NaN        NaN        NaN
# 4               NaN        NaN        NaN

# %%
# Compare results and results_pkl
results_pkl.reset_index(inplace=True, drop=True) # to have the same indexes

# %%
results_pkl.loc[:,"athletes"] = ["{}".format(results_pkl.loc[i,"athletes"]) for i in results_pkl.index] # To put the athletes in the same format
results_pkl = results_pkl.replace(r'^\s*$', None, regex=True) # To replace empty cells by nan
results_pkl = results_pkl.replace('NA', None) # To replace NA cells by nan
results_pkl = results_pkl.replace('nan', None) # To replace 'nan' cells by nan
results.compare(results_pkl) # If nothing outputs, it means they are equal
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Merge the dataframe hosts and results to have game season in results

# %%
results_hosts = hosts.merge(results, how='left', left_on='game_slug', right_on='slug_game')
results_hosts.head()
# Out:
#       game_slug         game_end_date       game_start_date game_location  \
# 0  beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z         China
# 1  beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z         China
# 2  beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z         China
# 3  beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z         China
# 4  beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z         China
#
#       game_name game_season  game_year discipline_title    event_title  \
# 0  Beijing 2022      Winter       2022          Curling  Mixed Doubles
# 1  Beijing 2022      Winter       2022          Curling  Mixed Doubles
# 2  Beijing 2022      Winter       2022          Curling  Mixed Doubles
# 3  Beijing 2022      Winter       2022          Curling  Mixed Doubles
# 4  Beijing 2022      Winter       2022          Curling  Mixed Doubles
#
#       slug_game  ...                                           athletes  \
# 0  beijing-2022  ...  [('Stefania CONSTANTINI', 'https://olympics.co...
# 1  beijing-2022  ...  [('Kristin SKASLIEN', 'https://olympics.com/en...
# 2  beijing-2022  ...  [('Almida DE VAL', 'https://olympics.com/en/at...
# 3  beijing-2022  ...  [('Jennifer DODDS', 'https://olympics.com/en/a...
# 4  beijing-2022  ...  [('Rachel HOMAN', 'https://olympics.com/en/ath...
#
#   rank_equal rank_position   country_name country_code country_3_letter_code  \
# 0      False             1          Italy           IT                   ITA
# 1      False             2         Norway           NO                   NOR
# 2      False             3         Sweden           SE                   SWE
# 3      False             4  Great Britain           GB                   GBR
# 4      False             5         Canada           CA                   CAN
#
#   athlete_url athlete_full_name value_unit value_type
# 0         NaN               NaN        NaN        NaN
# 1         NaN               NaN        NaN        NaN
# 2         NaN               NaN        NaN        NaN
# 3         NaN               NaN        NaN        NaN
# 4         NaN               NaN        NaN        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Take the Greece results

# %%
# Filter the data to get the Greece results
res_gr = results_hosts[(results_hosts["country_code"] == "GR")]

# %%
res_gr_summer = res_gr[res_gr["game_season"] == "Summer"]
res_gr_summer.head()
# Out:
#        game_slug         game_end_date       game_start_date game_location  \
# 4109  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 4196  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 4292  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 4881  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 5318  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
#
#        game_name game_season  game_year   discipline_title  \
# 4109  Tokyo 2020      Summer       2020           Shooting
# 4196  Tokyo 2020      Summer       2020           Shooting
# 4292  Tokyo 2020      Summer       2020           Shooting
# 4881  Tokyo 2020      Summer       2020       Cycling Road
# 5318  Tokyo 2020      Summer       2020  Artistic Swimming
#
#                event_title   slug_game  ...  \
# 4109  10m Air Pistol women  tokyo-2020  ...
# 4196      25m Pistol Women  tokyo-2020  ...
# 4292             Skeet Men  tokyo-2020  ...
# 4881       Men's Road Race  tokyo-2020  ...
# 5318                  Duet  tokyo-2020  ...
#
#                                                athletes rank_equal  \
# 4109                                                NaN      False
# 4196                                                NaN      False
# 4292                                                NaN      False
# 4881                                                NaN      False
# 5318  [('Clarissa JOHNSTON', 'https://olympics.com/e...      False
#
#      rank_position country_name country_code country_3_letter_code  \
# 4109             6       Greece           GR                   GRE
# 4196             6       Greece           GR                   GRE
# 4292            20       Greece           GR                   GRE
# 4881            63       Greece           GR                   GRE
# 5318           DNS       Greece           GR                   GRE
#
#                                             athlete_url  \
# 4109     https://olympics.com/en/athletes/anna-korakaki
# 4196     https://olympics.com/en/athletes/anna-korakaki
# 4292  https://olympics.com/en/athletes/nikolaos-mavr...
# 4881  https://olympics.com/en/athletes/polychronis-t...
# 5318                                                NaN
#
#            athlete_full_name value_unit value_type
# 4109           Anna KORAKAKI        NaN        NaN
# 4196           Anna KORAKAKI        NaN        NaN
# 4292    Nikolaos MAVROMMATIS        NaN        NaN
# 4881  Polychronis TZORTZAKIS        NaN        NaN
# 5318                     NaN        NaN        IRM
#
# [5 rows x 22 columns]

# %%
# Insert dates into the csv in order to use them in the dashboard
dates = []
for value in res_gr_summer["game_slug"].values:
    dates.append(int(value.split("-")[-1]))
    
res_gr_summer.insert(22, "date", np.array(dates))

# %%
res_gr_summer.head()
# Out:
#        game_slug         game_end_date       game_start_date game_location  \
# 4109  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 4196  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 4292  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 4881  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
# 5318  tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z         Japan
#
#        game_name game_season  game_year   discipline_title  \
# 4109  Tokyo 2020      Summer       2020           Shooting
# 4196  Tokyo 2020      Summer       2020           Shooting
# 4292  Tokyo 2020      Summer       2020           Shooting
# 4881  Tokyo 2020      Summer       2020       Cycling Road
# 5318  Tokyo 2020      Summer       2020  Artistic Swimming
#
#                event_title   slug_game  ... rank_equal rank_position  \
# 4109  10m Air Pistol women  tokyo-2020  ...      False             6
# 4196      25m Pistol Women  tokyo-2020  ...      False             6
# 4292             Skeet Men  tokyo-2020  ...      False            20
# 4881       Men's Road Race  tokyo-2020  ...      False            63
# 5318                  Duet  tokyo-2020  ...      False           DNS
#
#      country_name country_code country_3_letter_code  \
# 4109       Greece           GR                   GRE
# 4196       Greece           GR                   GRE
# 4292       Greece           GR                   GRE
# 4881       Greece           GR                   GRE
# 5318       Greece           GR                   GRE
#
#                                             athlete_url  \
# 4109     https://olympics.com/en/athletes/anna-korakaki
# 4196     https://olympics.com/en/athletes/anna-korakaki
# 4292  https://olympics.com/en/athletes/nikolaos-mavr...
# 4881  https://olympics.com/en/athletes/polychronis-t...
# 5318                                                NaN
#
#            athlete_full_name value_unit value_type  date
# 4109           Anna KORAKAKI        NaN        NaN  2020
# 4196           Anna KORAKAKI        NaN        NaN  2020
# 4292    Nikolaos MAVROMMATIS        NaN        NaN  2020
# 4881  Polychronis TZORTZAKIS        NaN        NaN  2020
# 5318                     NaN        NaN        IRM  2020
#
# [5 rows x 23 columns]

# %%
# Add a column with the sex of the athletes to use it in the dashboard
sex_list = []
for row in res_gr_summer.iterrows():
    if len(re.findall('Women', row[1].event_title)) > 0 or len(re.findall('women', row[1].event_title)) > 0:
        sex_list.append("Woman")
        
    elif len(re.findall('men', row[1].event_title)) > 0 or len(re.findall('Men', row[1].event_title)) > 0:
        sex_list.append("Man")
        
    else:
        sex_list.append("")
        
res_gr_summer.insert(23, "sexe", np.array(sex_list))
res_gr_summer[["event_title", "sexe"]]
# Out:
#                              event_title   sexe
# 4109                10m Air Pistol women  Woman
# 4196                    25m Pistol Women  Woman
# 4292                           Skeet Men    Man
# 4881                     Men's Road Race    Man
# 5318                                Duet
# ...                                  ...    ...
# 162791  Unlimited Class, Greco-Roman Men    Man
# 162796   heavyweight - one hand lift men    Man
# 162797   heavyweight - one hand lift men    Man
# 162800   heavyweight - two hand lift men    Man
# 162801   heavyweight - two hand lift men    Man
#
# [1413 rows x 2 columns]

# %%
# List the 10 first greek athletes
res_gr_summer.groupby(by="athlete_url").count().sort_values(by="medal_type", ascending=False)[:10]
# Out:
#                                                     game_slug  game_end_date  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas               4              4
# https://olympics.com/en/athletes/stamatios-niko...          2              2
# https://olympics.com/en/athletes/petros-galakto...          4              4
# https://olympics.com/en/athletes/dimosthenis-ta...          3              3
# https://olympics.com/en/athletes/anastasia-kele...          2              2
# https://olympics.com/en/athletes/mirella-manian...          2              2
# https://olympics.com/en/athletes/nikolaos-kakla...          5              5
# https://olympics.com/en/athletes/ilias-iliadis              4              4
# https://olympics.com/en/athletes/alexandros-nik...          4              4
# https://olympics.com/en/athletes/anna-korakaki              4              4
#
#                                                     game_start_date  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                     4
# https://olympics.com/en/athletes/stamatios-niko...                2
# https://olympics.com/en/athletes/petros-galakto...                4
# https://olympics.com/en/athletes/dimosthenis-ta...                3
# https://olympics.com/en/athletes/anastasia-kele...                2
# https://olympics.com/en/athletes/mirella-manian...                2
# https://olympics.com/en/athletes/nikolaos-kakla...                5
# https://olympics.com/en/athletes/ilias-iliadis                    4
# https://olympics.com/en/athletes/alexandros-nik...                4
# https://olympics.com/en/athletes/anna-korakaki                    4
#
#                                                     game_location  game_name  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                   4          4
# https://olympics.com/en/athletes/stamatios-niko...              2          2
# https://olympics.com/en/athletes/petros-galakto...              4          4
# https://olympics.com/en/athletes/dimosthenis-ta...              3          3
# https://olympics.com/en/athletes/anastasia-kele...              2          2
# https://olympics.com/en/athletes/mirella-manian...              2          2
# https://olympics.com/en/athletes/nikolaos-kakla...              5          5
# https://olympics.com/en/athletes/ilias-iliadis                  4          4
# https://olympics.com/en/athletes/alexandros-nik...              4          4
# https://olympics.com/en/athletes/anna-korakaki                  4          4
#
#                                                     game_season  game_year  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                 4          4
# https://olympics.com/en/athletes/stamatios-niko...            2          2
# https://olympics.com/en/athletes/petros-galakto...            4          4
# https://olympics.com/en/athletes/dimosthenis-ta...            3          3
# https://olympics.com/en/athletes/anastasia-kele...            2          2
# https://olympics.com/en/athletes/mirella-manian...            2          2
# https://olympics.com/en/athletes/nikolaos-kakla...            5          5
# https://olympics.com/en/athletes/ilias-iliadis                4          4
# https://olympics.com/en/athletes/alexandros-nik...            4          4
# https://olympics.com/en/athletes/anna-korakaki                4          4
#
#                                                     discipline_title  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                      4
# https://olympics.com/en/athletes/stamatios-niko...                 2
# https://olympics.com/en/athletes/petros-galakto...                 4
# https://olympics.com/en/athletes/dimosthenis-ta...                 3
# https://olympics.com/en/athletes/anastasia-kele...                 2
# https://olympics.com/en/athletes/mirella-manian...                 2
# https://olympics.com/en/athletes/nikolaos-kakla...                 5
# https://olympics.com/en/athletes/ilias-iliadis                     4
# https://olympics.com/en/athletes/alexandros-nik...                 4
# https://olympics.com/en/athletes/anna-korakaki                     4
#
#                                                     event_title  slug_game  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                 4          4
# https://olympics.com/en/athletes/stamatios-niko...            2          2
# https://olympics.com/en/athletes/petros-galakto...            4          4
# https://olympics.com/en/athletes/dimosthenis-ta...            3          3
# https://olympics.com/en/athletes/anastasia-kele...            2          2
# https://olympics.com/en/athletes/mirella-manian...            2          2
# https://olympics.com/en/athletes/nikolaos-kakla...            5          5
# https://olympics.com/en/athletes/ilias-iliadis                4          4
# https://olympics.com/en/athletes/alexandros-nik...            4          4
# https://olympics.com/en/athletes/anna-korakaki                4          4
#
#                                                     ...  rank_equal  \
# athlete_url                                         ...
# https://olympics.com/en/athletes/pyrros-dimas       ...           0
# https://olympics.com/en/athletes/stamatios-niko...  ...           0
# https://olympics.com/en/athletes/petros-galakto...  ...           0
# https://olympics.com/en/athletes/dimosthenis-ta...  ...           0
# https://olympics.com/en/athletes/anastasia-kele...  ...           0
# https://olympics.com/en/athletes/mirella-manian...  ...           0
# https://olympics.com/en/athletes/nikolaos-kakla...  ...           0
# https://olympics.com/en/athletes/ilias-iliadis      ...           3
# https://olympics.com/en/athletes/alexandros-nik...  ...           2
# https://olympics.com/en/athletes/anna-korakaki      ...           2
#
#                                                     rank_position  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                   4
# https://olympics.com/en/athletes/stamatios-niko...              2
# https://olympics.com/en/athletes/petros-galakto...              3
# https://olympics.com/en/athletes/dimosthenis-ta...              3
# https://olympics.com/en/athletes/anastasia-kele...              2
# https://olympics.com/en/athletes/mirella-manian...              2
# https://olympics.com/en/athletes/nikolaos-kakla...              5
# https://olympics.com/en/athletes/ilias-iliadis                  4
# https://olympics.com/en/athletes/alexandros-nik...              4
# https://olympics.com/en/athletes/anna-korakaki                  4
#
#                                                     country_name  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                  4
# https://olympics.com/en/athletes/stamatios-niko...             2
# https://olympics.com/en/athletes/petros-galakto...             4
# https://olympics.com/en/athletes/dimosthenis-ta...             3
# https://olympics.com/en/athletes/anastasia-kele...             2
# https://olympics.com/en/athletes/mirella-manian...             2
# https://olympics.com/en/athletes/nikolaos-kakla...             5
# https://olympics.com/en/athletes/ilias-iliadis                 4
# https://olympics.com/en/athletes/alexandros-nik...             4
# https://olympics.com/en/athletes/anna-korakaki                 4
#
#                                                     country_code  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                  4
# https://olympics.com/en/athletes/stamatios-niko...             2
# https://olympics.com/en/athletes/petros-galakto...             4
# https://olympics.com/en/athletes/dimosthenis-ta...             3
# https://olympics.com/en/athletes/anastasia-kele...             2
# https://olympics.com/en/athletes/mirella-manian...             2
# https://olympics.com/en/athletes/nikolaos-kakla...             5
# https://olympics.com/en/athletes/ilias-iliadis                 4
# https://olympics.com/en/athletes/alexandros-nik...             4
# https://olympics.com/en/athletes/anna-korakaki                 4
#
#                                                     country_3_letter_code  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                           4
# https://olympics.com/en/athletes/stamatios-niko...                      2
# https://olympics.com/en/athletes/petros-galakto...                      4
# https://olympics.com/en/athletes/dimosthenis-ta...                      3
# https://olympics.com/en/athletes/anastasia-kele...                      2
# https://olympics.com/en/athletes/mirella-manian...                      2
# https://olympics.com/en/athletes/nikolaos-kakla...                      5
# https://olympics.com/en/athletes/ilias-iliadis                          4
# https://olympics.com/en/athletes/alexandros-nik...                      4
# https://olympics.com/en/athletes/anna-korakaki                          4
#
#                                                     athlete_full_name  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                       4
# https://olympics.com/en/athletes/stamatios-niko...                  2
# https://olympics.com/en/athletes/petros-galakto...                  4
# https://olympics.com/en/athletes/dimosthenis-ta...                  3
# https://olympics.com/en/athletes/anastasia-kele...                  2
# https://olympics.com/en/athletes/mirella-manian...                  2
# https://olympics.com/en/athletes/nikolaos-kakla...                  5
# https://olympics.com/en/athletes/ilias-iliadis                      4
# https://olympics.com/en/athletes/alexandros-nik...                  4
# https://olympics.com/en/athletes/anna-korakaki                      4
#
#                                                     value_unit  value_type  \
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas                4           4
# https://olympics.com/en/athletes/stamatios-niko...           2           2
# https://olympics.com/en/athletes/petros-galakto...           0           0
# https://olympics.com/en/athletes/dimosthenis-ta...           2           2
# https://olympics.com/en/athletes/anastasia-kele...           0           0
# https://olympics.com/en/athletes/mirella-manian...           0           0
# https://olympics.com/en/athletes/nikolaos-kakla...           5           5
# https://olympics.com/en/athletes/ilias-iliadis               0           0
# https://olympics.com/en/athletes/alexandros-nik...           0           0
# https://olympics.com/en/athletes/anna-korakaki               1           1
#
#                                                     date  sexe
# athlete_url
# https://olympics.com/en/athletes/pyrros-dimas          4     4
# https://olympics.com/en/athletes/stamatios-niko...     2     2
# https://olympics.com/en/athletes/petros-galakto...     4     4
# https://olympics.com/en/athletes/dimosthenis-ta...     3     3
# https://olympics.com/en/athletes/anastasia-kele...     2     2
# https://olympics.com/en/athletes/mirella-manian...     2     2
# https://olympics.com/en/athletes/nikolaos-kakla...     5     5
# https://olympics.com/en/athletes/ilias-iliadis         4     4
# https://olympics.com/en/athletes/alexandros-nik...     4     4
# https://olympics.com/en/athletes/anna-korakaki         4     4
#
# [10 rows x 23 columns]

# %%
# Tests to see ho te get the name of the athletes
test = res_gr_summer.groupby(by="athlete_url").count().sort_values(by="medal_type", ascending=False)[:10]
names = []
for row in test.iterrows():
    names.append(row[0].split("/")[-1].split("-")[-1])
    
names
# Out:
# ['dimas',
#  'nikolopoulos',
#  'galaktopoulos',
#  'tampakos',
#  'kelesidou',
#  'tzelili',
#  'kaklamanakis',
#  'iliadis',
#  'nikolaidis',
#  'korakaki']

# %%
res_gr_by_date = res_gr_summer.groupby(by="date").count().medal_type

# %%
plt.figure()
plt.plot(res_gr_by_date.index, res_gr_by_date.values)
plt.xlabel("Année")
plt.ylabel("# médailles")
# Out:
# Text(0, 0.5, '# médailles')

# %%
# Export the result into a csv to be read by the dashboard
res_gr_summer.to_csv("data/gr_results.csv")

# %%
res_gr_summer.keys()
# Out:
# Index(['game_slug', 'game_end_date', 'game_start_date', 'game_location',
#        'game_name', 'game_season', 'game_year', 'discipline_title',
#        'event_title', 'slug_game', 'participant_type', 'medal_type',
#        'athletes', 'rank_equal', 'rank_position', 'country_name',
#        'country_code', 'country_3_letter_code', 'athlete_url',
#        'athlete_full_name', 'value_unit', 'value_type', 'date', 'sexe'],
#       dtype='object')
